# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Pearl Challenge data with dictionary.xlsx.csv')
df.head(5)
# Out:
#            FarmerID           State   REGION SEX        CITY  Zipcode  \
# 0  1002818465057450  MADHYA PRADESH  CENTRAL   M      BARELI   464668
# 1  1012300674433870           BIHAR     EAST   M      BANDRA   848125
# 2  1013472263587380  MADHYA PRADESH  CENTRAL   M  MALHARGARH   458556
# 3  1019525480704050     MAHARASHTRA     WEST   M     RENAPUR   413527
# 4  1021915867444260  MADHYA PRADESH  CENTRAL   F      KHURAI   470117
#
#       DISTRICT   VILLAGE MARITAL_STATUS Location  ...  \
# 0       RAISEN     Seoni              M      NaN  ...
# 1  MUZAFFARPUR   Namapur              M      NaN  ...
# 2     MANDSAUR   Billaud              M      NaN  ...
# 3        LATUR   Renapur              M      NaN  ...
# 4        SAGAR  Singhpur              M      NaN  ...
#
#        Rabi Seasons Agro Ecological Sub Zone in 2020  \
# 0  CENTRAL HIGHLANDS (MALWA AND BUNDELKHAND)  HOT...
# 1  DECCAN PLATEAU  (TELANGANA) AND EASTERN GHATS ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47970 entries, 0 to 47969
# Columns: 105 entries, FarmerID to Target_Variable/Total Income
# dtypes: float64(63), int64(4), object(38)
# memory usage: 38.4+ MB

# %%
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# FarmerID                                                                            int64
# State                                                                              object
# REGION                                                                             object
# SEX                                                                                object
# CITY                                                                               object
# Zipcode                                                                             int64
# DISTRICT                                                                           object
# VILLAGE                                                                            object
# MARITAL_STATUS                                                                     object
# Location                                                                           object
# ...

# %%
df.isnull().sum()
# Out:
# FarmerID                                                                              0
# State                                                                                 0
# REGION                                                                                0
# SEX                                                                                   0
# CITY                                                                                  0
# Zipcode                                                                               0
# DISTRICT                                                                              0
# VILLAGE                                                                               0
# MARITAL_STATUS                                                                        0
# Location                                                                          17030
# Address type                                                                      17030
# ...

# %%
df['Address type'] = df['Address type'].fillna('Nomad')
df['Address type'].head(20)
# Out:
# 0                 Nomad
# 1                 Nomad
# 2                 Nomad
# 3                 Nomad
# 4                 Nomad
# 5     Permanent Address
# 6                 Nomad
# 7     Permanent Address
# 8                 Nomad
# 9     Permanent Address
# 10    Permanent Address
# 11    Permanent Address
# 12    Permanent Address
# 13                Nomad
# 14    Permanent Address
# 15    Permanent Address
# 16    Permanent Address
# 17    Permanent Address
# 18      Current Address
# 19                Nomad
# Name: Address type, dtype: object

# %%
df_nomad = df[df['Address type'] == 'Nomad']

df_settled = df[df['Address type'] != 'Nomad']

# %%
df_nomad.to_csv('nomad.csv', index=False)

df_settled.to_csv('settled.csv', index=False)
